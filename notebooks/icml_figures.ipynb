# %% [markdown]
# # ICML Figures (Temporal Invariance)
#
# This notebook runs the figure pipeline using the codebase modules.

# %%
import os
import sys
import shutil
from getpass import getpass

# --- SAFELY CLEANUP ---
# Move to /content first so we aren't standing in the folder we delete
os.chdir("/content") 

if os.path.exists("/content/temporal_invariance"):
    print(">>> Cleaning up old directory...")
    shutil.rmtree("/content/temporal_invariance")

# --- CLONE ---
print(">>> Please enter your GitHub details:")
user = input("GitHub Username: ")
token = getpass("GitHub Token (Classic PAT with 'repo' scope): ")
repo = "temporal_invariance"

print(f">>> Cloning {user}/{repo}...")
# !git clone https://{user}:{token}@github.com/{user}/{repo}.git /content/temporal_invariance

# --- DEBUG: Verify Files ---
if os.path.exists("/content/temporal_invariance"):
    print("\n>>> File structure check:")
    # !ls -l /content/temporal_invariance
else:
    raise RuntimeError("Clone failed! The folder /content/temporal_invariance was not created.")

# --- SETUP ---
project_root = "/content/temporal_invariance"
os.chdir(project_root)
sys.path.append(os.path.join(project_root, "src"))

# --- INSTALL ---
print("\n>>> Installing dependencies...")
if os.path.exists("requirements.txt"):
    # !pip install -q -r requirements.txt
else:
    print("ERROR: requirements.txt not found in root!")

if os.path.exists("pyproject.toml") or os.path.exists("setup.py"):
    # !pip install -q -e .
else:
    print("ERROR: pyproject.toml not found! Cannot install package.")

# --- RUN ---
print("\n>>> Running pipeline...")
sys.path.insert(0, os.path.join(project_root, "src")) # Ensure src is first in path

try:
    from ti.scripts.run_figures import run_from_config
    run_from_config("configs/paper.yaml")
except ImportError:
    # If standard import fails, try reloading sys.modules or just run via command line
    print("Direct import failed (kernel refresh issue). Running via sub-process...")
    # !python3 src/ti/scripts/run_figures.py --config configs/paper.yaml
# Out:
# >>> Cleaning up old directory...
# >>> Please enter your GitHub details:
# >>> Cloning jinschofield/temporal_invariance...
# Cloning into '/content/temporal_invariance'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 69 (delta 2), reused 69 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 54.26 KiB | 27.13 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
#
# >>> File structure check:
# total 100
# drwxr-xr-x 2 root root  4096 Jan 18 03:55  configs
# drwxr-xr-x 2 root root  4096 Jan 18 03:55  notebooks
# -rw-r--r-- 1 root root   323 Jan 18 03:55  pyproject.toml
# -rw-r--r-- 1 root root  1655 Jan 18 03:55  README.md
# -rw-r--r-- 1 root root 72110 Jan 18 03:55 'rep_+_elliptical_(2).py'
# -rw-r--r-- 1 root root    52 Jan 18 03:55  requirements.txt
# drwxr-xr-x 2 root root  4096 Jan 18 03:55  scripts
# drwxr-xr-x 3 root root  4096 Jan 18 03:55  src
#
# >>> Installing dependencies...
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for temporal-invariance (pyproject.toml) ... done
#
# >>> Running pipeline...
# Direct import failed (kernel refresh issue). Running via sub-process...
# /usr/local/lib/python3.12/dist-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
#
# ============================================================================================
# ENV = Periodicity
# ============================================================================================
# Collecting offline dataset...
#
# >>> CRTR_R1
#   train:
#     train step   5000/20000 | loss=5.2360
#     train step  10000/20000 | loss=5.2389
#     train step  15000/20000 | loss=5.2426
#     train step  20000/20000 | loss=5.2433
#   probe/eval:
#   done | nuis_acc=0.139 (chance=0.125) | MI=0.001 | inv=0.0025 | xy_mse=0.0411
#
# >>> CRTR_R2
#   train:
#     train step   5000/20000 | loss=5.2369
#     train step  10000/20000 | loss=5.2379
#     train step  15000/20000 | loss=5.2441
#     train step  20000/20000 | loss=5.2374
#   probe/eval:
#   done | nuis_acc=0.132 (chance=0.125) | MI=0.000 | inv=0.0021 | xy_mse=0.0469
#
# >>> CRTR_R4
#   train:
#     train step   5000/20000 | loss=5.2416
#     train step  10000/20000 | loss=5.2491
#     train step  15000/20000 | loss=5.2505
#     train step  20000/20000 | loss=5.2452
#   probe/eval:
#   done | nuis_acc=0.137 (chance=0.125) | MI=0.000 | inv=0.0026 | xy_mse=0.0448
#
# >>> CRTR_R8
#   train:
#     train step   5000/20000 | loss=5.2444
#     train step  10000/20000 | loss=5.2411
#     train step  15000/20000 | loss=5.2532
#     train step  20000/20000 | loss=5.2581
#   probe/eval:
#   done | nuis_acc=0.126 (chance=0.125) | MI=0.000 | inv=0.0022 | xy_mse=0.0407
#
# >>> CRTR_R16
#   train:
#     train step   5000/20000 | loss=5.2653
#     train step  10000/20000 | loss=5.2844
#     train step  15000/20000 | loss=5.2698
#     train step  20000/20000 | loss=5.2540
#   probe/eval:
#   done | nuis_acc=0.158 (chance=0.125) | MI=0.001 | inv=0.0019 | xy_mse=0.0420
#
# >>> CRTR_R32
#   train:
#     train step   5000/20000 | loss=5.2672
#     train step  10000/20000 | loss=5.2953
#     train step  15000/20000 | loss=5.2977
#     train step  20000/20000 | loss=5.2554
#   probe/eval:
#   done | nuis_acc=0.151 (chance=0.125) | MI=0.009 | inv=0.0031 | xy_mse=0.0399
#
# >>> CRTR_R64
#   train:
#     train step   5000/20000 | loss=5.3363
#     train step  10000/20000 | loss=5.3241
#     train step  15000/20000 | loss=5.2921
#     train step  20000/20000 | loss=5.2974
#   probe/eval:
#   done | nuis_acc=0.256 (chance=0.125) | MI=0.581 | inv=0.5083 | xy_mse=0.0318
#
# >>> IDM
#   train:
#     train step   5000/20000 | loss=1.1542
#     train step  10000/20000 | loss=1.0132
#     train step  15000/20000 | loss=0.8886
#     train step  20000/20000 | loss=0.8556
#   probe/eval:
#   done | nuis_acc=0.238 (chance=0.125) | MI=0.065 | inv=0.0891 | xy_mse=0.0650
#
# >>> ICM
#   train:
#     train step   5000/20000 | loss=1.1090
#     train step  10000/20000 | loss=1.0075
#     train step  15000/20000 | loss=0.9366
#     train step  20000/20000 | loss=0.8440
#   probe/eval:
#   done | nuis_acc=0.149 (chance=0.125) | MI=0.032 | inv=0.0301 | xy_mse=0.0464
#
# >>> RND
#   train:
#     train step   5000/20000 | loss=0.0000
#     train step  10000/20000 | loss=0.0000
#     train step  15000/20000 | loss=0.0000
#     train step  20000/20000 | loss=0.0000
#   probe/eval:
#   done | nuis_acc=0.845 (chance=0.125) | MI=0.604 | inv=0.1889 | xy_mse=0.1185
#
# >>> BISCUIT
#     BISCUIT step   5000/20000 | loss=2.0930
#     BISCUIT step  10000/20000 | loss=0.5838
#     BISCUIT step  15000/20000 | loss=0.5566
#     BISCUIT step  20000/20000 | loss=0.5237
#   done | nuis_acc=1.000 (chance=0.125) | MI=1.720 | inv=75.8898 | xy_mse=0.2685
#
# >>> CBM
#     CBM: train g...
#       g step   5000/10000
#       g step  10000/10000
#     CBM: train psi...
# [Backup] Zipping outputs -> /content/temporal_invariance/results_latest.zip ...
# [Backup] Saved to /content/temporal_invariance/results_latest.zip
#       psi step   5000/10000
#       psi step  10000/10000
#     CBM: train reward predictor...
#       rew step   5000/10000
#       rew step  10000/10000
#     CBM: estimate CMI(dynamics) ...
#     CBM: estimate CMI(reward) ...
# /usr/local/lib/python3.12/dist-packages/torch/nn/init.py:566: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
#   done | nuis_acc=0.119 (chance=0.125) | MI=0.000 | inv=0.0000 | xy_mse=0.2685 | abstraction=0/5
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
#
# ============================================================================================
# ENV = Slippery
# ============================================================================================
# Collecting offline dataset...
#
# >>> CRTR_R1
#   train:
#     train step   5000/20000 | loss=5.2404
#     train step  10000/20000 | loss=5.2449
#     train step  15000/20000 | loss=5.2350
#     train step  20000/20000 | loss=5.2422
#   probe/eval:
#   done | nuis_acc=0.324 (chance=0.333) | MI=0.000 | inv=0.0010 | xy_mse=0.0445
#
# >>> CRTR_R2
#   train:
#     train step   5000/20000 | loss=5.2460
#     train step  10000/20000 | loss=5.2394
#     train step  15000/20000 | loss=5.2407
#     train step  20000/20000 | loss=5.2428
#   probe/eval:
#   done | nuis_acc=0.349 (chance=0.333) | MI=0.000 | inv=0.0013 | xy_mse=0.0464
#
# >>> CRTR_R4
#   train:
#     train step   5000/20000 | loss=5.2534
#     train step  10000/20000 | loss=5.2385
#     train step  15000/20000 | loss=5.2443
#     train step  20000/20000 | loss=5.2365
#   probe/eval:
#   done | nuis_acc=0.307 (chance=0.333) | MI=0.000 | inv=0.0008 | xy_mse=0.0456
#
# >>> CRTR_R8
#   train:
#     train step   5000/20000 | loss=5.2542
#     train step  10000/20000 | loss=5.2382
#     train step  15000/20000 | loss=5.2462
#     train step  20000/20000 | loss=5.2604
#   probe/eval:
#   done | nuis_acc=0.380 (chance=0.333) | MI=0.000 | inv=0.0009 | xy_mse=0.0471
#
# >>> CRTR_R16
#   train:
#     train step   5000/20000 | loss=5.2556
#     train step  10000/20000 | loss=5.2869
#     train step  15000/20000 | loss=5.2501
#     train step  20000/20000 | loss=5.2504
#   probe/eval:
#   done | nuis_acc=0.311 (chance=0.333) | MI=0.000 | inv=0.0010 | xy_mse=0.0466
#
# >>> CRTR_R32
#   train:
#     train step   5000/20000 | loss=5.2588
#     train step  10000/20000 | loss=5.3235
#     train step  15000/20000 | loss=5.3069
#     train step  20000/20000 | loss=5.3350
#   probe/eval:
#   done | nuis_acc=0.352 (chance=0.333) | MI=0.000 | inv=0.0009 | xy_mse=0.0373
#
# >>> CRTR_R64
#   train:
#     train step   5000/20000 | loss=5.2576
#     train step  10000/20000 | loss=5.2668
#     train step  15000/20000 | loss=5.3546
#     train step  20000/20000 | loss=5.3048
#   probe/eval:
#   done | nuis_acc=0.344 (chance=0.333) | MI=0.000 | inv=0.0011 | xy_mse=0.0360
#
# >>> IDM
#   train:
#     train step   5000/20000 | loss=1.3866
#     train step  10000/20000 | loss=1.3865
#     train step  15000/20000 | loss=1.3862
#     train step  20000/20000 | loss=1.3802
#   probe/eval:
#   done | nuis_acc=0.678 (chance=0.333) | MI=0.197 | inv=0.1583 | xy_mse=0.1543
#        (slippery extra) delay_ID_acc=0.314
#
# >>> ICM
#   train:
#     train step   5000/20000 | loss=1.3867
#     train step  10000/20000 | loss=1.3888
#     train step  15000/20000 | loss=1.3821
#     train step  20000/20000 | loss=1.3857
#   probe/eval:
#   done | nuis_acc=0.570 (chance=0.333) | MI=0.054 | inv=0.0149 | xy_mse=0.2519
#        (slippery extra) delay_ID_acc=0.292
#
# >>> RND
#   train:
#     train step   5000/20000 | loss=0.0000
#     train step  10000/20000 | loss=0.0000
#     train step  15000/20000 | loss=0.0000
#     train step  20000/20000 | loss=0.0000
#   probe/eval:
#   done | nuis_acc=0.947 (chance=0.333) | MI=0.463 | inv=0.1270 | xy_mse=0.0885
#        (slippery extra) delay_ID_acc=0.292
#
# >>> BISCUIT
#     BISCUIT step   5000/20000 | loss=1.1873
#     BISCUIT step  10000/20000 | loss=1.2092
#     BISCUIT step  15000/20000 | loss=1.2188
# [Backup] Zipping outputs -> /content/temporal_invariance/results_latest.zip ...
# [Backup] Saved to /content/temporal_invariance/results_latest.zip
#     BISCUIT step  20000/20000 | loss=1.2043
#   done | nuis_acc=0.334 (chance=0.333) | MI=0.001 | inv=0.0000 | xy_mse=0.2695
#        (slippery extra) delay_ID_acc=0.241
#
# >>> CBM
#     CBM: train g...
#       g step   5000/10000
#       g step  10000/10000
#     CBM: train psi...
#       psi step   5000/10000
#       psi step  10000/10000
#     CBM: train reward predictor...
#       rew step   5000/10000
#       rew step  10000/10000
#     CBM: estimate CMI(dynamics) ...
#     CBM: estimate CMI(reward) ...
# /usr/local/lib/python3.12/dist-packages/torch/nn/init.py:566: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
#   done | nuis_acc=0.330 (chance=0.333) | MI=0.000 | inv=0.0000 | xy_mse=0.2707 | abstraction=0/5
#        (slippery extra) delay_ID_acc=0.241
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
#
# ============================================================================================
# ENV = Teacup Maze
# ============================================================================================
# Collecting offline dataset...
#   Teacups special fraction = 0.283 (11363/40192)
#
# >>> CRTR_R1
#   train:
#     train step   5000/20000 | loss=5.3179
#     train step  10000/20000 | loss=5.3151
#     train step  15000/20000 | loss=5.3114
#     train step  20000/20000 | loss=5.3075
#   probe/eval:
#   done | nuis_acc=0.286 (chance=0.250) | MI=0.013 | inv=0.1499 | xy_mse=0.0291
#
# >>> CRTR_R2
#   train:
#     train step   5000/20000 | loss=5.3121
#     train step  10000/20000 | loss=5.3207
#     train step  15000/20000 | loss=5.3134
#     train step  20000/20000 | loss=5.3246
#   probe/eval:
#   done | nuis_acc=0.258 (chance=0.250) | MI=0.006 | inv=0.1312 | xy_mse=0.0290
#
# >>> CRTR_R4
#   train:
#     train step   5000/20000 | loss=5.3148
#     train step  10000/20000 | loss=5.3220
#     train step  15000/20000 | loss=5.3267
#     train step  20000/20000 | loss=5.2983
#   probe/eval:
#   done | nuis_acc=0.293 (chance=0.250) | MI=0.008 | inv=0.1442 | xy_mse=0.0286
#
# >>> CRTR_R8
#   train:
#     train step   5000/20000 | loss=5.3297
#     train step  10000/20000 | loss=5.3445
#     train step  15000/20000 | loss=5.3093
#     train step  20000/20000 | loss=5.3079
#   probe/eval:
#   done | nuis_acc=0.269 (chance=0.250) | MI=0.008 | inv=0.1400 | xy_mse=0.0295
#
# >>> CRTR_R16
#   train:
#     train step   5000/20000 | loss=5.2961
#     train step  10000/20000 | loss=5.3068
#     train step  15000/20000 | loss=5.3468
#     train step  20000/20000 | loss=5.3264
#   probe/eval:
#   done | nuis_acc=0.268 (chance=0.250) | MI=0.009 | inv=0.1321 | xy_mse=0.0285
#
# >>> CRTR_R32
#   train:
#     train step   5000/20000 | loss=5.3323
#     train step  10000/20000 | loss=5.3765
#     train step  15000/20000 | loss=5.3665
#     train step  20000/20000 | loss=5.3979
#   probe/eval:
#   done | nuis_acc=0.253 (chance=0.250) | MI=0.006 | inv=0.1400 | xy_mse=0.0297
#
# >>> CRTR_R64
#   train:
#     train step   5000/20000 | loss=5.3997
#     train step  10000/20000 | loss=5.3954
#     train step  15000/20000 | loss=5.4182
#     train step  20000/20000 | loss=5.4275
#   probe/eval:
#   done | nuis_acc=0.301 (chance=0.250) | MI=0.012 | inv=0.1404 | xy_mse=0.0303
#
# >>> IDM
#   train:
#     train step   5000/20000 | loss=0.9816
#     train step  10000/20000 | loss=0.7612
#     train step  15000/20000 | loss=0.6549
#     train step  20000/20000 | loss=0.5072
#   probe/eval:
#   done | nuis_acc=0.960 (chance=0.250) | MI=0.801 | inv=0.5429 | xy_mse=0.0047
#
# >>> ICM
#   train:
#     train step   5000/20000 | loss=1.0116
#     train step  10000/20000 | loss=0.7559
#     train step  15000/20000 | loss=0.6010
#     train step  20000/20000 | loss=0.5832
#   probe/eval:
#   done | nuis_acc=0.885 (chance=0.250) | MI=0.456 | inv=0.1834 | xy_mse=0.0043
#
# >>> RND
#   train:
# [Backup] Zipping outputs -> /content/temporal_invariance/results_latest.zip ...
# [Backup] Saved to /content/temporal_invariance/results_latest.zip
#     train step   5000/20000 | loss=0.0000
#     train step  10000/20000 | loss=0.0000
#     train step  15000/20000 | loss=0.0000
#     train step  20000/20000 | loss=0.0000
#   probe/eval:
#   done | nuis_acc=0.995 (chance=0.250) | MI=0.914 | inv=0.4374 | xy_mse=0.0933
#
# >>> BISCUIT
#     BISCUIT step   5000/20000 | loss=0.7988
#     BISCUIT step  10000/20000 | loss=0.7892
#     BISCUIT step  15000/20000 | loss=0.8614
#     BISCUIT step  20000/20000 | loss=0.8517
#   done | nuis_acc=0.261 (chance=0.250) | MI=0.001 | inv=0.0000 | xy_mse=0.2833
#
# >>> CBM
#     CBM: train g...
#       g step   5000/10000
#       g step  10000/10000
#     CBM: train psi...
#       psi step   5000/10000
#       psi step  10000/10000
#     CBM: train reward predictor...
#       rew step   5000/10000
#       rew step  10000/10000
#     CBM: estimate CMI(dynamics) ...
#     CBM: estimate CMI(reward) ...
# /usr/local/lib/python3.12/dist-packages/torch/nn/init.py:566: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
#   done | nuis_acc=0.271 (chance=0.250) | MI=0.001 | inv=0.0000 | xy_mse=0.2809 | abstraction=0/5
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
# /content/temporal_invariance/src/ti/plotting/plots.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=names, y=vals, palette=palette)
#
# ============================================================================================
# ELLIPTICAL BONUS + SCALARS | ENV = Periodicity
# ============================================================================================
# Collecting offline dataset...
#
# >>> CRTR_R1
#   train...    train step   5000/20000 | loss=5.2445
#     train step  10000/20000 | loss=5.2401
#     train step  15000/20000 | loss=5.2401
#     train step  20000/20000 | loss=5.2415
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R2
#   train...    train step   5000/20000 | loss=5.2449
#     train step  10000/20000 | loss=5.2430
#     train step  15000/20000 | loss=5.2402
#     train step  20000/20000 | loss=5.2400
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R4
#   train...    train step   5000/20000 | loss=5.2434
#     train step  10000/20000 | loss=5.2534
#     train step  15000/20000 | loss=5.2440
#     train step  20000/20000 | loss=5.2460
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R8
#   train...    train step   5000/20000 | loss=5.2632
#     train step  10000/20000 | loss=5.2509
#     train step  15000/20000 | loss=5.2466
#     train step  20000/20000 | loss=5.2428
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R16
#   train...    train step   5000/20000 | loss=5.2657
# [Backup] Zipping outputs -> /content/temporal_invariance/results_latest.zip ...
# [Backup] Saved to /content/temporal_invariance/results_latest.zip
#     train step  10000/20000 | loss=5.2551
#     train step  15000/20000 | loss=5.2738
#     train step  20000/20000 | loss=5.2559
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R32
#   train...    train step   5000/20000 | loss=5.2399
#     train step  10000/20000 | loss=5.2550
#     train step  15000/20000 | loss=5.2711
#     train step  20000/20000 | loss=5.2576
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R64
#   train...    train step   5000/20000 | loss=5.3192
#     train step  10000/20000 | loss=5.3016
#     train step  15000/20000 | loss=5.3202
#     train step  20000/20000 | loss=5.2638
#   build A...  heat+scalars...  done.
#
# >>> IDM
#   train...    train step   5000/20000 | loss=1.1046
#     train step  10000/20000 | loss=0.9928
#     train step  15000/20000 | loss=0.9451
#     train step  20000/20000 | loss=0.8309
#   build A...  heat+scalars...  done.
#
# >>> ICM
#   train...    train step   5000/20000 | loss=1.1146
#     train step  10000/20000 | loss=1.0010
#     train step  15000/20000 | loss=0.9234
#     train step  20000/20000 | loss=0.8695
#   build A...  heat+scalars...  done.
#
# >>> RND
#   train...    train step   5000/20000 | loss=0.0000
#     train step  10000/20000 | loss=0.0000
#     train step  15000/20000 | loss=0.0000
#     train step  20000/20000 | loss=0.0000
#   build A...  heat+scalars...  done.
#
# >>> BISCUIT
#   train...    BISCUIT step   5000/20000 | loss=0.7768
#     BISCUIT step  10000/20000 | loss=0.5513
#     BISCUIT step  15000/20000 | loss=0.5536
#     BISCUIT step  20000/20000 | loss=0.5757
#   build A...  heat+scalars...  done.
#
# >>> CBM
#   train...    CBM: train g...
#       g step   5000/10000
#       g step  10000/10000
#     CBM: train psi...
#       psi step   5000/10000
# [Backup] Zipping outputs -> /content/temporal_invariance/results_latest.zip ...
#       psi step  10000/10000
#     CBM: train reward predictor...
# [Backup] Saved to /content/temporal_invariance/results_latest.zip
#       rew step   5000/10000
#       rew step  10000/10000
#     CBM: estimate CMI(dynamics) ...
#     CBM: estimate CMI(reward) ...
#   build A...  heat+scalars...  done.
#
# ============================================================================================
# ELLIPTICAL BONUS + SCALARS | ENV = Slippery
# ============================================================================================
# Collecting offline dataset...
#
# >>> CRTR_R1
#   train...    train step   5000/20000 | loss=5.2426
#     train step  10000/20000 | loss=5.2335
#     train step  15000/20000 | loss=5.2404
#     train step  20000/20000 | loss=5.2374
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R2
#   train...    train step   5000/20000 | loss=5.2427
#     train step  10000/20000 | loss=5.2430
#     train step  15000/20000 | loss=5.2379
#     train step  20000/20000 | loss=5.2427
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R4
#   train...    train step   5000/20000 | loss=5.2474
#     train step  10000/20000 | loss=5.2479
#     train step  15000/20000 | loss=5.2411
#     train step  20000/20000 | loss=5.2363
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R8
#   train...    train step   5000/20000 | loss=5.2487
#     train step  10000/20000 | loss=5.2488
#     train step  15000/20000 | loss=5.2400
#     train step  20000/20000 | loss=5.2640
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R16
#   train...    train step   5000/20000 | loss=5.2582
#     train step  10000/20000 | loss=5.2380
#     train step  15000/20000 | loss=5.2626
#     train step  20000/20000 | loss=5.2642
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R32
#   train...    train step   5000/20000 | loss=5.2784
#     train step  10000/20000 | loss=5.2947
#     train step  15000/20000 | loss=5.2936
#     train step  20000/20000 | loss=5.2604
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R64
#   train...    train step   5000/20000 | loss=5.3704
#     train step  10000/20000 | loss=5.2566
#     train step  15000/20000 | loss=5.3306
#     train step  20000/20000 | loss=5.3923
#   build A...  heat+scalars...  done.
#
# >>> IDM
#   train...    train step   5000/20000 | loss=1.3818
#     train step  10000/20000 | loss=1.3862
#     train step  15000/20000 | loss=1.3822
#     train step  20000/20000 | loss=1.3840
#   build A...  heat+scalars...  done.
#
# >>> ICM
#   train...    train step   5000/20000 | loss=1.3872
#     train step  10000/20000 | loss=1.3913
#     train step  15000/20000 | loss=1.3855
#     train step  20000/20000 | loss=1.3864
#   build A...  heat+scalars...  done.
#
# >>> RND
#   train...    train step   5000/20000 | loss=0.0000
#     train step  10000/20000 | loss=0.0000
#     train step  15000/20000 | loss=0.0000
#     train step  20000/20000 | loss=0.0000
#   build A...  heat+scalars...  done.
#
# >>> BISCUIT
#   train...    BISCUIT step   5000/20000 | loss=1.1843
#     BISCUIT step  10000/20000 | loss=1.1872
#     BISCUIT step  15000/20000 | loss=1.2057
#     BISCUIT step  20000/20000 | loss=1.1952
#   build A...  heat+scalars...  done.
#
# >>> CBM
#   train...    CBM: train g...
#       g step   5000/10000
# [Backup] Zipping outputs -> /content/temporal_invariance/results_latest.zip ...
# [Backup] Saved to /content/temporal_invariance/results_latest.zip
#       g step  10000/10000
#     CBM: train psi...
#       psi step   5000/10000
#       psi step  10000/10000
#     CBM: train reward predictor...
#       rew step   5000/10000
#       rew step  10000/10000
#     CBM: estimate CMI(dynamics) ...
#     CBM: estimate CMI(reward) ...
#   build A...  heat+scalars...  done.
#
# ============================================================================================
# ELLIPTICAL BONUS + SCALARS | ENV = Teacup Maze
# ============================================================================================
# Collecting offline dataset...
#
# >>> CRTR_R1
#   train...    train step   5000/20000 | loss=5.3075
#     train step  10000/20000 | loss=5.3196
#     train step  15000/20000 | loss=5.3167
#     train step  20000/20000 | loss=5.3206
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R2
#   train...    train step   5000/20000 | loss=5.3134
#     train step  10000/20000 | loss=5.3086
#     train step  15000/20000 | loss=5.3127
#     train step  20000/20000 | loss=5.3336
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R4
#   train...    train step   5000/20000 | loss=5.3408
#     train step  10000/20000 | loss=5.3164
#     train step  15000/20000 | loss=5.3191
#     train step  20000/20000 | loss=5.3057
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R8
#   train...    train step   5000/20000 | loss=5.3224
#     train step  10000/20000 | loss=5.3179
#     train step  15000/20000 | loss=5.3243
#     train step  20000/20000 | loss=5.3102
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R16
#   train...    train step   5000/20000 | loss=5.3098
#     train step  10000/20000 | loss=5.3461
#     train step  15000/20000 | loss=5.3105
#     train step  20000/20000 | loss=5.3055
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R32
#   train...    train step   5000/20000 | loss=5.3760
#     train step  10000/20000 | loss=5.3500
#     train step  15000/20000 | loss=5.3495
#     train step  20000/20000 | loss=5.3282
#   build A...  heat+scalars...  done.
#
# >>> CRTR_R64
#   train...    train step   5000/20000 | loss=5.3484
#     train step  10000/20000 | loss=5.4202
#     train step  15000/20000 | loss=5.2957
#     train step  20000/20000 | loss=5.3812
#   build A...  heat+scalars...  done.
#
# >>> IDM
#   train...    train step   5000/20000 | loss=1.0015
#     train step  10000/20000 | loss=0.7718
#     train step  15000/20000 | loss=0.6587
#     train step  20000/20000 | loss=0.5394
#   build A...  heat+scalars...  done.
#
# >>> ICM
#   train...    train step   5000/20000 | loss=1.0230
#     train step  10000/20000 | loss=0.8300
#     train step  15000/20000 | loss=0.6444
#     train step  20000/20000 | loss=0.5468
#   build A...  heat+scalars...  done.
#
# >>> RND
#   train...    train step   5000/20000 | loss=0.0000
#     train step  10000/20000 | loss=0.0000
#     train step  15000/20000 | loss=0.0000
#     train step  20000/20000 | loss=0.0000
#   build A...  heat+scalars...  done.
#
# >>> BISCUIT
#   train...    BISCUIT step   5000/20000 | loss=0.8004
#     BISCUIT step  10000/20000 | loss=0.8770
# [Backup] Zipping outputs -> /content/temporal_invariance/results_latest.zip ...
# [Backup] Saved to /content/temporal_invariance/results_latest.zip
#     BISCUIT step  15000/20000 | loss=0.8196
#     BISCUIT step  20000/20000 | loss=0.8601
#   build A...  heat+scalars...  done.
#
# >>> CBM
#   train...    CBM: train g...
#       g step   5000/10000
#       g step  10000/10000
#     CBM: train psi...
#       psi step   5000/10000
#       psi step  10000/10000
#     CBM: train reward predictor...
#       rew step   5000/10000
#       rew step  10000/10000
#     CBM: estimate CMI(dynamics) ...
#     CBM: estimate CMI(reward) ...
#   build A...  heat+scalars...  done.
#
# ============================================================================================
# ELLIPTICAL BONUS + SCALARS | ENV = Teacup Maze  (ONLY)
# ============================================================================================
# Collecting offline dataset (once)...
#
# >>> CRTR_R1
#     train step   5000/20000 | loss=5.3179
#     train step  10000/20000 | loss=5.3429
#     train step  15000/20000 | loss=5.3156
#     train step  20000/20000 | loss=5.3159
#   heat_std_mean (LOW)           = 0.003086
#   orbit_ratio W/(B+eps) (LOW)   = 0.763974
#   bonus→nuis acc/MI (LOW)       = 0.2615 / 0.0000
#   cup contrast in-out (HIGH)    = -0.001097
#   inside_std_mean (LOW)         = 0.002657
#   inside_rel_std_mean (LOW)     = 0.139750
#
# >>> CRTR_R2
#     train step   5000/20000 | loss=5.3044
#     train step  10000/20000 | loss=5.3077
#     train step  15000/20000 | loss=5.3105
#     train step  20000/20000 | loss=5.3065
#   heat_std_mean (LOW)           = 0.003124
#   orbit_ratio W/(B+eps) (LOW)   = 1.393643
#   bonus→nuis acc/MI (LOW)       = 0.2345 / 0.0000
#   cup contrast in-out (HIGH)    = -0.001337
#   inside_std_mean (LOW)         = 0.002851
#   inside_rel_std_mean (LOW)     = 0.137236
#
# >>> CRTR_R4
#     train step   5000/20000 | loss=5.3190
#     train step  10000/20000 | loss=5.3236
#     train step  15000/20000 | loss=5.3312
#     train step  20000/20000 | loss=5.2955
#   heat_std_mean (LOW)           = 0.002788
#   orbit_ratio W/(B+eps) (LOW)   = 0.600342
#   bonus→nuis acc/MI (LOW)       = 0.3288 / 0.0031
#   cup contrast in-out (HIGH)    = -0.001039
#   inside_std_mean (LOW)         = 0.002767
#   inside_rel_std_mean (LOW)     = 0.144059
#
# >>> CRTR_R8
#     train step   5000/20000 | loss=5.3008
#     train step  10000/20000 | loss=5.3241
#     train step  15000/20000 | loss=5.3442
#     train step  20000/20000 | loss=5.3024
#   heat_std_mean (LOW)           = 0.002997
#   orbit_ratio W/(B+eps) (LOW)   = 1.004872
#   bonus→nuis acc/MI (LOW)       = 0.2318 / 0.0000
#   cup contrast in-out (HIGH)    = -0.001292
#   inside_std_mean (LOW)         = 0.003370
#   inside_rel_std_mean (LOW)     = 0.170690
#
# >>> CRTR_R16
#     train step   5000/20000 | loss=5.3341
#     train step  10000/20000 | loss=5.3496
#     train step  15000/20000 | loss=5.3304
#     train step  20000/20000 | loss=5.3230
#   heat_std_mean (LOW)           = 0.003217
#   orbit_ratio W/(B+eps) (LOW)   = 0.656197
#   bonus→nuis acc/MI (LOW)       = 0.2439 / 0.0000
#   cup contrast in-out (HIGH)    = -0.002797
#   inside_std_mean (LOW)         = 0.002546
#   inside_rel_std_mean (LOW)     = 0.145011
#
# >>> CRTR_R32
#     train step   5000/20000 | loss=5.3130
#     train step  10000/20000 | loss=5.3608
#     train step  15000/20000 | loss=5.3368
#     train step  20000/20000 | loss=5.3459
#   heat_std_mean (LOW)           = 0.002087
#   orbit_ratio W/(B+eps) (LOW)   = 0.388519
#   bonus→nuis acc/MI (LOW)       = 0.2547 / 0.0031
#   cup contrast in-out (HIGH)    = -0.000940
#   inside_std_mean (LOW)         = 0.002198
#   inside_rel_std_mean (LOW)     = 0.102433
#
# >>> CRTR_R64
#     train step   5000/20000 | loss=5.4426
#     train step  10000/20000 | loss=5.5096
#     train step  15000/20000 | loss=5.4032
#     train step  20000/20000 | loss=5.4174
#   heat_std_mean (LOW)           = 0.002603
#   orbit_ratio W/(B+eps) (LOW)   = 0.438725
#   bonus→nuis acc/MI (LOW)       = 0.2992 / 0.0016
#   cup contrast in-out (HIGH)    = -0.001217
#   inside_std_mean (LOW)         = 0.002448
#   inside_rel_std_mean (LOW)     = 0.127435
#
# >>> IDM
#     train step   5000/20000 | loss=1.0025
#     train step  10000/20000 | loss=0.7997
#     train step  15000/20000 | loss=0.6158
#     train step  20000/20000 | loss=0.5314
#   heat_std_mean (LOW)           = 0.002051
#   orbit_ratio W/(B+eps) (LOW)   = 1.433710
#   bonus→nuis acc/MI (LOW)       = 0.2534 / 0.0000
#   cup contrast in-out (HIGH)    = 0.000200
#   inside_std_mean (LOW)         = 0.002369
#   inside_rel_std_mean (LOW)     = 0.115865
#
# >>> ICM
#     train step   5000/20000 | loss=1.0097
#     train step  10000/20000 | loss=0.8046
#     train step  15000/20000 | loss=0.6541
# [Backup] Zipping outputs -> /content/temporal_invariance/results_latest.zip ...
# [Backup] Saved to /content/temporal_invariance/results_latest.zip
#     train step  20000/20000 | loss=0.5030
#   heat_std_mean (LOW)           = 0.003031
#   orbit_ratio W/(B+eps) (LOW)   = 1.992408
#   bonus→nuis acc/MI (LOW)       = 0.2601 / 0.0006
#   cup contrast in-out (HIGH)    = -0.002868
#   inside_std_mean (LOW)         = 0.002677
#   inside_rel_std_mean (LOW)     = 0.141088
#
# >>> RND
#     train step   5000/20000 | loss=0.0000
#     train step  10000/20000 | loss=0.0000
#     train step  15000/20000 | loss=0.0000
#     train step  20000/20000 | loss=0.0000
#   heat_std_mean (LOW)           = 0.002706
#   orbit_ratio W/(B+eps) (LOW)   = 1.276774
#   bonus→nuis acc/MI (LOW)       = 0.2385 / 0.0003
#   cup contrast in-out (HIGH)    = -0.001905
#   inside_std_mean (LOW)         = 0.002567
#   inside_rel_std_mean (LOW)     = 0.118137
#
# >>> BISCUIT
#     BISCUIT step   5000/20000 | loss=0.9005
#     BISCUIT step  10000/20000 | loss=0.7976
#     BISCUIT step  15000/20000 | loss=0.8502
#     BISCUIT step  20000/20000 | loss=0.8223
#   heat_std_mean (LOW)           = 0.000198
#   orbit_ratio W/(B+eps) (LOW)   = 1.145996
#   bonus→nuis acc/MI (LOW)       = 0.2736 / 0.0002
#   cup contrast in-out (HIGH)    = -0.000130
#   inside_std_mean (LOW)         = 0.000166
#   inside_rel_std_mean (LOW)     = 0.022072
#
# >>> CBM
#     CBM: train g...
#       g step   5000/10000
#       g step  10000/10000
#     CBM: train psi...
#       psi step   5000/10000
#       psi step  10000/10000
#     CBM: train reward predictor...
#       rew step   5000/10000
#       rew step  10000/10000
#     CBM: estimate CMI(dynamics) ...
#     CBM: estimate CMI(reward) ...
#   heat_std_mean (LOW)           = 0.000000
#   orbit_ratio W/(B+eps) (LOW)   = 0.000000
#   bonus→nuis acc/MI (LOW)       = 0.2453 / 0.0000
#   cup contrast in-out (HIGH)    = 0.000000
#   inside_std_mean (LOW)         = 0.000000
#   inside_rel_std_mean (LOW)     = 0.000000

# %%
# 1. List all generated plots
# !find /content/temporal_invariance/outputs/figures -name "*.png"

# 2. Download the ZIP of everything (This is the most reliable way)
from google.colab import files
files.download("/content/temporal_invariance/results_latest.zip")
# Out:
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_IDM_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_ICM_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R16_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R4_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R32_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R64_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CBM_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R2_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R1_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_BISCUIT_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CBM_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R64_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_IDM_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R1_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_BISCUIT_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R4_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_ICM_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_RND_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_RND_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_IDM_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R4_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R2_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_BISCUIT_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_BISCUIT_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R32_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CBM_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_IDM_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R16_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_RND_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CBM_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_RND_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_RND_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_IDM_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R16_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_RND_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R16_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R32_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R2_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R16_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R8_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CBM_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_ICM_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R1_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R8_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_BISCUIT_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R8_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R64_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R32_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R32_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R4_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R16_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R64_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R64_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_RND_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R2_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_BISCUIT_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_ICM_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R8_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R1_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R2_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CBM_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R4_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R4_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R64_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_RND_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_ICM_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R32_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R8_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_BISCUIT_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CBM_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R32_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R1_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_IDM_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_IDM_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R8_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R4_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R2_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CBM_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R1_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_IDM_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_BISCUIT_heat_mean_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R16_heat_std_cup.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R64_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R1_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R8_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R2_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_ICM_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R64_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R32_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_CRTR_R16_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R1_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R2_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/slippery_CRTR_R8_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/teacup_CRTR_R4_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_ICM_heat_mean.png
# /content/temporal_invariance/outputs/figures/20260118_035601/elliptical_heatmaps/periodicity_ICM_heat_std.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/slippery_nuis_mi.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/teacup_inv.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/periodicity_xy_mse.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/teacup_nuis_mi.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/teacup_xy_mse.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/teacup_nuis_acc.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/periodicity_inv.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/periodicity_nuis_mi.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/slippery_xy_mse.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/slippery_inv.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/periodicity_nuis_acc.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/slippery_delay_id.png
# /content/temporal_invariance/outputs/figures/20260118_035601/rep_sweep/slippery_nuis_acc.png

# %%
import base64
from IPython.display import HTML

def create_download_link(filename):
    with open(filename, "rb") as f:
        data = f.read()
    b64 = base64.b64encode(data).decode()
    payload = f"data:application/zip;base64,{b64}"
    html = f'<a download="{filename.split("/")[-1]}" href="{payload}" target="_blank">Click here to download {filename.split("/")[-1]}</a>'
    return HTML(html)

# Create the link for the latest results
create_download_link("/content/temporal_invariance/results_latest.zip")
# Out:
# Failed to connect to the remote Jupyter Server 'https://8080-gpu-h100-s-kkb-ass1c2-3i4kxcy7z9a28-c.asia-southeast1-2.prod.colab.dev/'. Verify the server is running and reachable.

# %%
import shutil
import os

# Ensure Drive is mounted
if not os.path.exists('/content/drive'):
    from google.colab import drive
    drive.mount('/content/drive')

# Copy
src = "/content/temporal_invariance/results_latest.zip"
dst = "/content/drive/MyDrive/results_latest.zip"

if os.path.exists(src):
    shutil.copy(src, dst)
    print(f"✅ Copied to Google Drive: {dst}")
else:
    print("❌ Source file not found yet (maybe wait for the 15-min zipper or run it manually).")
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel) (icml_figures.ipynb)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:24dad659-81f8-4198-8297-0acbe2b50646
